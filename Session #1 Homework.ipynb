# %% [markdown]
# # Session #1 Homework

# %% [markdown]
# ### Question 1

# %% [markdown]
# What's the version of NumPy that you installed?

# %%
import pandas as pd
import numpy as np

# %%
np.__version__
# Out:
# '1.19.2'

# %% [markdown]
# ### Question 2

# %% [markdown]
# What's the version of Pandas?

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ### Question 3

# %% [markdown]
# What's the average price of BMW cars in the dataset?

# %%
# Import the data sets
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Out:
# --2021-09-13 11:09:17--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: ‘data.csv.1’
#
# data.csv.1          100%[===================>]   1.41M  --.-KB/s    in 0.01s
#
# 2021-09-13 11:09:17 (143 MB/s) - ‘data.csv.1’ saved [1475504/1475504]

# %%
#Read data sets and convert it to pandas dataframe
df= pd.read_csv("data.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
BMW_Data =df[df["Make"]=="BMW"]
BMW_Data
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
AVG_BMW = BMW_Data.MSRP.mean()
AVG_BMW
# Out:
# 61546.76347305389

# %% [markdown]
# ### Question 4

# %% [markdown]
# Select a subset of cars after year 2015 (inclusive, i.e. 2015 and after). How many of them have missing values for Engine HP?

# %%
modern_cars = df[df["Year"]>=2015]
modern_cars
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
modern_cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ### Question 5

# %% [markdown]
# Calculate the average "Engine HP" in the dataset.
# Use the fillna method and to fill the missing values in "Engine HP" with the mean value from the previous step.
# Now, calcualte the average of "Engine HP" again.
# Has it changed?

# %%
df["Engine HP"].mean()
# Out:
# 249.38607007176023

# %%
Engine_HP_full = df["Engine HP"].fillna(df["Engine HP"].mean())
Engine_HP_full
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
Engine_HP_full.isnull().sum()
# Out:
# 0

# %%
Engine_HP_full.mean()
# Out:
# 249.38607007176023

# %%
## As we see 'engine HP' average didn't change

# %% [markdown]
# ### Question 6

# %% [markdown]
# Select all the "Rolls-Royce" cars from the dataset.
#
# Select only columns "Engine HP", "Engine Cylinders", "highway MPG".
#
# Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 7 rows).
#
# Get the underlying NumPy array. Let's call it X.
#
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
#
# Invert XTX.
#
# What's the sum of all the elements of the result?

# %%
R_cars = df[df["Make"]=="Rolls-Royce"]
R_cars
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls-Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls-Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# ...

# %%
duplicates_droped = R_cars[["Engine HP", "Engine Cylinders", "highway MPG"]].drop_duplicates()
duplicates_droped
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X= duplicates_droped.to_numpy()
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
T = X*X
T
# Out:
# array([[1.05625e+05, 6.40000e+01, 2.25000e+02],
#        [3.16969e+05, 1.44000e+02, 3.61000e+02],
#        [3.16969e+05, 1.44000e+02, 4.41000e+02],
#        [3.16969e+05, 1.44000e+02, 4.00000e+02],
#        [1.03684e+05, 1.44000e+02, 2.25000e+02],
#        [2.05209e+05, 1.44000e+02, 3.61000e+02],
#        [3.89376e+05, 1.44000e+02, 4.41000e+02]])

# %%
TXT = T*X
TXT
# Out:
# array([[3.43281250e+07, 5.12000000e+02, 3.37500000e+03],
#        [1.78453547e+08, 1.72800000e+03, 6.85900000e+03],
#        [1.78453547e+08, 1.72800000e+03, 9.26100000e+03],
#        [1.78453547e+08, 1.72800000e+03, 8.00000000e+03],
#        [3.33862480e+07, 1.72800000e+03, 3.37500000e+03],
#        [9.29596770e+07, 1.72800000e+03, 6.85900000e+03],
#        [2.42970624e+08, 1.72800000e+03, 9.26100000e+03]])

# %%
TXT_INV =np.linalg.inv(TXT)
TXT_INV
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-20-e7962522dc42> in <module>
# ----> 1 TXT_INV =np.linalg.inv(TXT)
#       2 TXT_INV
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     539     a, wrap = _makearray(a)
#     540     _assert_stacked_2d(a)
# --> 541     _assert_stacked_square(a)
#     542     t, result_t = _commonType(a)
#     543
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/numpy/linalg/linalg.py in _assert_stacked_square(*arrays)
#     202         m, n = a.shape[-2:]
#     203         if m != n:
# --> 204             raise LinAlgError('Last 2 dimensions of the array must be square')
#     205
#     206 def _assert_finite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %% [markdown]
# ### Questions 7

# %% [markdown]
# Create an array y with values [1000, 1100, 900, 1200, 1000, 850, 1300].
#
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#
# What's the value of the first element of w?.
